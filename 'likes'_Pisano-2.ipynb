# %% [markdown]
# #  Section 1
# ## these are the import functions

# %%
import json
import pandas as pd
import matplotlib as plt

# %% [markdown]
# # Section 2
# ## these are loading functions for the likes

# %%
df = pd.DataFrame(dict)
df.head()
# Out:
#                                    likes_media_likes
# 0  {'title': 'ksuphimu', 'string_list_data': [{'h...
# 1  {'title': 'ellas.photo.diary', 'string_list_da...
# 2  {'title': 'rach_czap', 'string_list_data': [{'...
# 3  {'title': 'maddietakesflixs', 'string_list_dat...
# 4  {'title': 'ellabellesstyle', 'string_list_data...

# %%
dict.keys()
# Out:
# dict_keys(['likes_media_likes'])

# %%
df_tidy = pd.DataFrame(dict['likes_media_likes'])
df_tidy.head()
# Out:
#                title                                   string_list_data
# 0           ksuphimu  [{'href': 'https://www.instagram.com/p/DNyQ6sQ...
# 1  ellas.photo.diary  [{'href': 'https://www.instagram.com/p/DNwGO08...
# 2          rach_czap  [{'href': 'https://www.instagram.com/p/DNtDzHY...
# 3   maddietakesflixs  [{'href': 'https://www.instagram.com/p/DNs7qUq...
# 4    ellabellesstyle  [{'href': 'https://www.instagram.com/p/DNqbDJc...

# %% [markdown]
# # Section 4

# %%
df_tidy['string_list_data'].iloc[0]
# Out:
# [{'href': 'https://www.instagram.com/p/DNyQ6sQ4hN-/',
#   'value': 'ð\x9f\x91\x8d',
#   'timestamp': 1756144103}]

# %%
type (df_tidy['string_list_data'].iloc[0])
# Out:
# list

# %%
len(df_tidy['string_list_data'].iloc[0])
# Out:
# 1

# %%
df_tidy['string_list_data'].iloc[0][0]
# Out:
# {'href': 'https://www.instagram.com/p/DNyQ6sQ4hN-/',
#  'value': 'ð\x9f\x91\x8d',
#  'timestamp': 1756144103}

# %%
df_tidy['string_list_data'].iloc[0][0]['timestamp']
# Out:
# 1756144103

# %%
df_tidy['Time of Like'] = [ i[0]['timestamp'] for i in df_tidy['string_list_data']]
df_tidy.head()
# Out:
#                title                                   string_list_data  \
# 0           ksuphimu  [{'href': 'https://www.instagram.com/p/DNyQ6sQ...
# 1  ellas.photo.diary  [{'href': 'https://www.instagram.com/p/DNwGO08...
# 2          rach_czap  [{'href': 'https://www.instagram.com/p/DNtDzHY...
# 3   maddietakesflixs  [{'href': 'https://www.instagram.com/p/DNs7qUq...
# 4    ellabellesstyle  [{'href': 'https://www.instagram.com/p/DNqbDJc...
#
#    Time of Like
# 0    1756144103
# 1    1756070934
# 2    1755967367
# 3    1755965810
# 4    1755897259

# %%
from datetime import datetime
df_tidy['Date of Like'] = [ datetime.fromtimestamp (i[0]['timestamp']) for i in df_tidy['string_list_data']]

# %%
df_tidy['href'] = [ i[0]['href'] for i in df_tidy['string_list_data']]
df_tidy.head()
# Out:
#                title                                   string_list_data  \
# 0           ksuphimu  [{'href': 'https://www.instagram.com/p/DNyQ6sQ...
# 1  ellas.photo.diary  [{'href': 'https://www.instagram.com/p/DNwGO08...
# 2          rach_czap  [{'href': 'https://www.instagram.com/p/DNtDzHY...
# 3   maddietakesflixs  [{'href': 'https://www.instagram.com/p/DNs7qUq...
# 4    ellabellesstyle  [{'href': 'https://www.instagram.com/p/DNqbDJc...
#
#    Time of Like        Date of Like                                      href
# 0    1756144103 2025-08-25 13:48:23  https://www.instagram.com/p/DNyQ6sQ4hN-/
# 1    1756070934 2025-08-24 17:28:54  https://www.instagram.com/p/DNwGO085L4w/
# 2    1755967367 2025-08-23 12:42:47  https://www.instagram.com/p/DNtDzHYWkjp/
# 3    1755965810 2025-08-23 12:16:50  https://www.instagram.com/p/DNs7qUqWkDi/
# 4    1755897259 2025-08-22 17:14:19  https://www.instagram.com/p/DNqbDJcRyQi/

# %%
df_tidy.drop(columns = ['string_list_data'])
# Out:
#                   title  Time of Like        Date of Like  \
# 0              ksuphimu    1756144103 2025-08-25 13:48:23
# 1     ellas.photo.diary    1756070934 2025-08-24 17:28:54
# 2             rach_czap    1755967367 2025-08-23 12:42:47
# 3      maddietakesflixs    1755965810 2025-08-23 12:16:50
# 4       ellabellesstyle    1755897259 2025-08-22 17:14:19
# ...                 ...           ...                 ...
# 5416    haydensummerall    1496543582 2017-06-03 22:33:02
# 5417         livvpisano    1492813045 2017-04-21 18:17:25
# 5418        global.papi    1491594050 2017-04-07 15:40:50
# 5419      kendallvertes    1491577980 2017-04-07 11:13:00
# 5420      karalynnjoyce    1451325652 2015-12-28 13:00:52
#
#                                           href
# 0     https://www.instagram.com/p/DNyQ6sQ4hN-/
# 1     https://www.instagram.com/p/DNwGO085L4w/
# 2     https://www.instagram.com/p/DNtDzHYWkjp/
# 3     https://www.instagram.com/p/DNs7qUqWkDi/
# ...

# %% [markdown]
# # Section 5

# %%
df_tidy.groupby('title').count().sort_values('Time of Like', ascending = False)
# Out:
#                     string_list_data  Time of Like  Date of Like  href
# title
# alleycati                         59            59            59    59
# evameloche                        58            58            58    58
# riotgrrrlboy                      53            53            53    53
# archivegalaxy                     48            48            48    48
# hazebreyer_                       47            47            47    47
# ...                              ...           ...           ...   ...
# hallowsteen                        1             1             1     1
# hamddol                            1             1             1     1
# hammymemes_                        1             1             1     1
# hamzahthefantastic                 1             1             1     1
# zynntopia                          1             1             1     1
#
# [2694 rows x 4 columns]

# %% [markdown]
# ## Section 6

# %% [markdown]
# #### A hypothesis I am trying to figure out is what advertisers have in-person stores to shop from and which one are simply (most likely scams). This will be done by using my personal instagram data to see what advertisers/ads pop up on my account.

# %% [markdown]
# ### Algorithmic and situation context is what i'm expecting for the data to turn out with. Just to see if the ads have an in-person store would be interesting to find out.

# %% [markdown]
# ### The variables I am searching for are the Companies name and the true of false statement of having an in-person store for their products. The unit of analysis I am looking for is if the companie does infact have a store that is in person that one can buy from. And a comparison to see if the head(10-20) stores in the top 20 of my results have an in-person store and if so, how many out of the 10-20 in the heading.

# %% [markdown]
# ## Section 7

# %% [markdown]
# #### ads_information with instagram_ads_and_businesses will tell me what advertisers are (who) and if they have in-store-in-person buyable products.

# %% [markdown]
# ## Section 8

# %%
path=r"/Users/ceciliapisano/Downloads/instagram-cece.pisano-2025-08-25-UMGrkIl3/ads_information/instagram_ads_and_businesses/advertisers_using_your_activity_or_information.json"

# %% [markdown]
# ## Section 9

# %% [markdown]
# convert the data to tidy dataframe

# %%
with open("/Users/ceciliapisano/Downloads/instagram-cece.pisano-2025-08-25-UMGrkIl3/ads_information/instagram_ads_and_businesses/advertisers_using_your_activity_or_information.json", "r") as f:
    data = json.load(f)

# %%
print(data)
# Out:
# {'ig_custom_audiences_all_types': [{'advertiser_name': 'Navigator Support', 'has_data_file_custom_audience': True, 'has_remarketing_custom_audience': True, 'has_in_person_store_visit': False}, {'advertiser_name': 'BURGA', 'has_data_file_custom_audience': True, 'has_remarketing_custom_audience': True, 'has_in_person_store_visit': False}, {'advertiser_name': 'Peppermayo', 'has_data_file_custom_audience': True, 'has_remarketing_custom_audience': True, 'has_in_person_store_visit': False}, {'advertiser_name': 'Shopify Business Manager', 'has_data_file_custom_audience': True, 'has_remarketing_custom_audience': True, 'has_in_person_store_visit': False}, {'advertiser_name': 'Meshki', 'has_data_file_custom_audience': True, 'has_remarketing_custom_audience': True, 'has_in_person_store_visit': False}, {'advertiser_name': 'DrinkNowadays', 'has_data_file_custom_audience': True, 'has_remarketing_custom_audience': True, 'has_in_person_store_visit': False}, {'advertiser_name': 'madison fiore', 'has_
# ...

# %%
type(data)
data.keys()
# Out:
# dict_keys(['ig_custom_audiences_all_types'])

# %%
type(data['ig_custom_audiences_all_types'])
# Out:
# list

# %%
len(data['ig_custom_audiences_all_types'])
# Out:
# 7935

# %%
data['ig_custom_audiences_all_types'][0]
# Out:
# {'advertiser_name': 'Navigator Support',
#  'has_data_file_custom_audience': True,
#  'has_remarketing_custom_audience': True,
#  'has_in_person_store_visit': False}

# %%
ads_df = pd.DataFrame(data['ig_custom_audiences_all_types'])

# %%
ads_df.head(10)
# Out:
#             advertiser_name  has_data_file_custom_audience  \
# 0         Navigator Support                           True
# 1                     BURGA                           True
# 2                Peppermayo                           True
# 3  Shopify Business Manager                           True
# 4                    Meshki                           True
# 5             DrinkNowadays                           True
# 6             madison fiore                           True
# 7            Adsmurai Spain                           True
# 8            enewton design                           True
# 9         Victoria's Secret                           True
#
#    has_remarketing_custom_audience  has_in_person_store_visit
# 0                             True                      False
# 1                             True                      False
# 2                             True                      False
# 3                             True                      False
# ...

# %%
ads_df_tidy = ads_df.drop(columns = ['has_data_file_custom_audience','has_remarketing_custom_audience'])

# %%
ads_df_tidy.head(20)
# Out:
#              advertiser_name  has_in_person_store_visit
# 0          Navigator Support                      False
# 1                      BURGA                      False
# 2                 Peppermayo                      False
# 3   Shopify Business Manager                      False
# 4                     Meshki                      False
# 5              DrinkNowadays                      False
# 6              madison fiore                      False
# 7             Adsmurai Spain                      False
# 8             enewton design                      False
# 9          Victoria's Secret                      False
# 10             House of Good                      False
# 11                  Dynamite                      False
# 12                    Garage                      False
# 13                    Kroger                      False
# 14                Birdy Grey                      False
# 15         Intuit QuickBooks                      False
# ...

# %% [markdown]
# # Section 10

# %% [markdown]
# ### This data represents the companys that are being advertised on my instagram page, on my feed and on the stories throughtout my time looking. The rows of the advertisers name represents what companies ads are and who the company is. The second row of has_in_person_store_visit was the data I was searching for. My hypothesis stated to see what companies that are advertised/reccommended have in store and in person products to buy-- none of them do.

# %% [markdown]
# ### I'd like to be able to change the names of the headers ofr the columns but other than that I am satisfied.

# %% [markdown]
# ### This data can test my data by going through the json file I loaded and seeing what advertisers do in fact have stores that you can purchase products through and that it is an in person store. The data wouldve been better if instagram allowed you to see what actual products may have been featured on the ad and that would be on the data.
